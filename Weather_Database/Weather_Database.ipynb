# %%
# Import Dependencies
import pandas as pd
import numpy as np
import requests
import time
import matplotlib.pyplot as plt
from scipy.stats import linregress
from datetime import datetime
from citipy import citipy

from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
#len(cities)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | bouar
# Processing Record 4 of Set 1 | castro
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | alofi
# Processing Record 9 of Set 1 | gobabis
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | saldanha
# Processing Record 14 of Set 1 | ilulissat
# Processing Record 15 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 1 | lebu
# Processing Record 17 of Set 1 | emirdag
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | parrita
# Processing Record 20 of Set 1 | jizan
# Processing Record 21 of Set 1 | assiniboia
# Processing Record 22 of Set 1 | peniche
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | garissa
# Processing Record 28 of Set 1 | cherskiy
# Processing Record 29 of Set 1 | hithadhoo
# Processing Record 30 of Set 1 | butaritari
# Processing Record 31 of Set 1 | bredasdorp
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | maceio
# Processing Record 34 of Set 1 | bugiri
# Processing Record 35 of Set 1 | simplicio mendes
# Processing Record 36 of Set 1 | bambous virieux
# Processing Record 37 of Set 1 | mogadishu
# Processing Record 38 of Set 1 | georgetown
# Processing Record 39 of Set 1 | barrow
# Processing Record 40 of Set 1 | khatanga
# Processing Record 41 of Set 1 | clarence town
# Processing Record 42 of Set 1 | mahbubabad
# Processing Record 43 of Set 1 | mar del plata
# Processing Record 44 of Set 1 | huercal-overa
# Processing Record 45 of Set 1 | upernavik
# Processing Record 46 of Set 1 | kodiak
# Processing Record 47 of Set 1 | beringovskiy
# Processing Record 48 of Set 1 | galgani
# City not found. Skipping...
# Processing Record 49 of Set 1 | polovinnoye
# Processing Record 50 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 1 of Set 2 | egvekinot
# Processing Record 2 of Set 2 | kavieng
# Processing Record 3 of Set 2 | ribeira grande
# Processing Record 4 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 5 of Set 2 | fairbanks
# Processing Record 6 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 2 | alenquer
# Processing Record 8 of Set 2 | nuuk
# Processing Record 9 of Set 2 | inhambane
# Processing Record 10 of Set 2 | ambilobe
# Processing Record 11 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 12 of Set 2 | hobart
# Processing Record 13 of Set 2 | geraldton
# Processing Record 14 of Set 2 | lighthouse point
# Processing Record 15 of Set 2 | tongsa
# City not found. Skipping...
# Processing Record 16 of Set 2 | torbay
# Processing Record 17 of Set 2 | busselton
# Processing Record 18 of Set 2 | beloha
# Processing Record 19 of Set 2 | beira
# Processing Record 20 of Set 2 | kismayo
# Processing Record 21 of Set 2 | laguna
# Processing Record 22 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 23 of Set 2 | avera
# Processing Record 24 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 2 | saskylakh
# Processing Record 26 of Set 2 | taoudenni
# Processing Record 27 of Set 2 | nyurba
# Processing Record 28 of Set 2 | yilan
# Processing Record 29 of Set 2 | tiksi
# Processing Record 30 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 2 | anloga
# Processing Record 32 of Set 2 | sidmouth
# Processing Record 33 of Set 2 | buala
# Processing Record 34 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 2 | aksarka
# Processing Record 37 of Set 2 | cuamba
# Processing Record 38 of Set 2 | kindu
# Processing Record 39 of Set 2 | severo-kurilsk
# Processing Record 40 of Set 2 | tuktoyaktuk
# Processing Record 41 of Set 2 | luderitz
# Processing Record 42 of Set 2 | katsuura
# Processing Record 43 of Set 2 | nome
# Processing Record 44 of Set 2 | raudeberg
# Processing Record 45 of Set 2 | jamestown
# Processing Record 46 of Set 2 | tromso
# Processing Record 47 of Set 2 | hambantota
# Processing Record 48 of Set 2 | saint george
# Processing Record 49 of Set 2 | umm durman
# City not found. Skipping...
# Processing Record 50 of Set 2 | markova
# Processing Record 1 of Set 3 | lokosovo
# Processing Record 2 of Set 3 | tuburan
# Processing Record 3 of Set 3 | dongsheng
# Processing Record 4 of Set 3 | micheweni
# Processing Record 5 of Set 3 | rawson
# Processing Record 6 of Set 3 | yellowknife
# Processing Record 7 of Set 3 | okhotsk
# Processing Record 8 of Set 3 | aklavik
# Processing Record 9 of Set 3 | vila velha
# Processing Record 10 of Set 3 | chuy
# Processing Record 11 of Set 3 | bikin
# Processing Record 12 of Set 3 | sitka
# Processing Record 13 of Set 3 | balkanabat
# Processing Record 14 of Set 3 | faya
# Processing Record 15 of Set 3 | timizart
# Processing Record 16 of Set 3 | lujan
# Processing Record 17 of Set 3 | bishop auckland
# Processing Record 18 of Set 3 | fort saint james
# Processing Record 19 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 3 | pevek
# Processing Record 21 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 3 | kensington
# Processing Record 23 of Set 3 | varniai
# Processing Record 24 of Set 3 | xining
# Processing Record 25 of Set 3 | bluff
# Processing Record 26 of Set 3 | cabo san lucas
# Processing Record 27 of Set 3 | sinop
# Processing Record 28 of Set 3 | tasiilaq
# Processing Record 29 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 30 of Set 3 | nouadhibou
# Processing Record 31 of Set 3 | avarua
# Processing Record 32 of Set 3 | senj
# Processing Record 33 of Set 3 | boa vista
# Processing Record 34 of Set 3 | joshimath
# Processing Record 35 of Set 3 | coronel vivida
# Processing Record 36 of Set 3 | zruc nad sazavou
# Processing Record 37 of Set 3 | flin flon
# Processing Record 38 of Set 3 | lujiang
# Processing Record 39 of Set 3 | galveston
# Processing Record 40 of Set 3 | paramonga
# Processing Record 41 of Set 3 | hermanus
# Processing Record 42 of Set 3 | salinopolis
# Processing Record 43 of Set 3 | carnarvon
# Processing Record 44 of Set 3 | aykhal
# Processing Record 45 of Set 3 | pemba
# Processing Record 46 of Set 3 | port blair
# Processing Record 47 of Set 3 | victoria
# Processing Record 48 of Set 3 | westport
# Processing Record 49 of Set 3 | nikolskoye
# Processing Record 50 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 4 | souillac
# Processing Record 2 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 4 | nola
# Processing Record 4 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 4 | dillon
# Processing Record 6 of Set 4 | zhigalovo
# Processing Record 7 of Set 4 | mwinilunga
# Processing Record 8 of Set 4 | airai
# Processing Record 9 of Set 4 | talnakh
# Processing Record 10 of Set 4 | deputatskiy
# Processing Record 11 of Set 4 | port alfred
# Processing Record 12 of Set 4 | norman wells
# Processing Record 13 of Set 4 | toktogul
# Processing Record 14 of Set 4 | asyut
# Processing Record 15 of Set 4 | mendi
# Processing Record 16 of Set 4 | broome
# Processing Record 17 of Set 4 | ancud
# Processing Record 18 of Set 4 | san patricio
# Processing Record 19 of Set 4 | portland
# Processing Record 20 of Set 4 | la ronge
# Processing Record 21 of Set 4 | tabou
# Processing Record 22 of Set 4 | ilebo
# Processing Record 23 of Set 4 | east london
# Processing Record 24 of Set 4 | morondava
# Processing Record 25 of Set 4 | bubaque
# Processing Record 26 of Set 4 | cambrils
# Processing Record 27 of Set 4 | shasta lake
# Processing Record 28 of Set 4 | gorontalo
# Processing Record 29 of Set 4 | bathsheba
# Processing Record 30 of Set 4 | evensk
# Processing Record 31 of Set 4 | mataram
# Processing Record 32 of Set 4 | richards bay
# Processing Record 33 of Set 4 | ryotsu
# Processing Record 34 of Set 4 | port elizabeth
# Processing Record 35 of Set 4 | falam
# Processing Record 36 of Set 4 | baykit
# Processing Record 37 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 4 | arraial do cabo
# Processing Record 39 of Set 4 | kaitangata
# Processing Record 40 of Set 4 | oistins
# Processing Record 41 of Set 4 | mugumu
# Processing Record 42 of Set 4 | lavrentiya
# Processing Record 43 of Set 4 | talaya
# Processing Record 44 of Set 4 | doctor arroyo
# Processing Record 45 of Set 4 | tuatapere
# Processing Record 46 of Set 4 | qaanaaq
# Processing Record 47 of Set 4 | havoysund
# Processing Record 48 of Set 4 | tazovskiy
# Processing Record 49 of Set 4 | lata
# Processing Record 50 of Set 4 | kirakira
# Processing Record 1 of Set 5 | provideniya
# Processing Record 2 of Set 5 | padang
# Processing Record 3 of Set 5 | poum
# Processing Record 4 of Set 5 | iqaluit
# Processing Record 5 of Set 5 | qandala
# Processing Record 6 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 7 of Set 5 | sergeyevka
# Processing Record 8 of Set 5 | nanortalik
# Processing Record 9 of Set 5 | omboue
# Processing Record 10 of Set 5 | hofn
# Processing Record 11 of Set 5 | mersing
# Processing Record 12 of Set 5 | khasan
# Processing Record 13 of Set 5 | ponta do sol
# Processing Record 14 of Set 5 | sabha
# Processing Record 15 of Set 5 | mackay
# Processing Record 16 of Set 5 | faanui
# Processing Record 17 of Set 5 | disraeli
# Processing Record 18 of Set 5 | matara
# Processing Record 19 of Set 5 | mahebourg
# Processing Record 20 of Set 5 | aripuana
# Processing Record 21 of Set 5 | strezhevoy
# Processing Record 22 of Set 5 | pisco
# Processing Record 23 of Set 5 | wanaka
# Processing Record 24 of Set 5 | constitucion
# Processing Record 25 of Set 5 | port macquarie
# Processing Record 26 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 27 of Set 5 | pitimbu
# Processing Record 28 of Set 5 | kilindoni
# Processing Record 29 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 5 | pangnirtung
# Processing Record 32 of Set 5 | nizwa
# Processing Record 33 of Set 5 | hovd
# Processing Record 34 of Set 5 | seinajoki
# Processing Record 35 of Set 5 | road town
# Processing Record 36 of Set 5 | dikson
# Processing Record 37 of Set 5 | nagato
# Processing Record 38 of Set 5 | dhidhdhoo
# Processing Record 39 of Set 5 | belmonte
# Processing Record 40 of Set 5 | naze
# Processing Record 41 of Set 5 | hamilton
# Processing Record 42 of Set 5 | guantanamo
# Processing Record 43 of Set 5 | cartagena
# Processing Record 44 of Set 5 | cidreira
# Processing Record 45 of Set 5 | mawlaik
# Processing Record 46 of Set 5 | schortens
# Processing Record 47 of Set 5 | sisimiut
# Processing Record 48 of Set 5 | makarska
# Processing Record 49 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 50 of Set 5 | thompson
# Processing Record 1 of Set 6 | bengkulu
# Processing Record 2 of Set 6 | port lincoln
# Processing Record 3 of Set 6 | pilibhit
# Processing Record 4 of Set 6 | santa maria
# Processing Record 5 of Set 6 | cabedelo
# Processing Record 6 of Set 6 | harlingen
# Processing Record 7 of Set 6 | hasaki
# Processing Record 8 of Set 6 | luwuk
# Processing Record 9 of Set 6 | sept-iles
# Processing Record 10 of Set 6 | adrar
# Processing Record 11 of Set 6 | chokurdakh
# Processing Record 12 of Set 6 | santo angelo
# Processing Record 13 of Set 6 | omsukchan
# Processing Record 14 of Set 6 | beaufort
# Processing Record 15 of Set 6 | karlshamn
# Processing Record 16 of Set 6 | guerrero negro
# Processing Record 17 of Set 6 | axim
# Processing Record 18 of Set 6 | arys
# Processing Record 19 of Set 6 | three hills
# Processing Record 20 of Set 6 | lakes entrance
# Processing Record 21 of Set 6 | vorontsovka
# Processing Record 22 of Set 6 | san cristobal
# Processing Record 23 of Set 6 | ahipara
# Processing Record 24 of Set 6 | lagoa
# Processing Record 25 of Set 6 | khani
# Processing Record 26 of Set 6 | sobolevo
# Processing Record 27 of Set 6 | bonavista
# Processing Record 28 of Set 6 | khilok
# Processing Record 29 of Set 6 | shu
# Processing Record 30 of Set 6 | olafsvik
# Processing Record 31 of Set 6 | eyemouth
# Processing Record 32 of Set 6 | crawfordsville
# Processing Record 33 of Set 6 | grand baie
# Processing Record 34 of Set 6 | ust-nera
# Processing Record 35 of Set 6 | ananas
# Processing Record 36 of Set 6 | takhtamygda
# Processing Record 37 of Set 6 | janakkala
# Processing Record 38 of Set 6 | awjilah
# Processing Record 39 of Set 6 | tevaitoa
# Processing Record 40 of Set 6 | ayan
# Processing Record 41 of Set 6 | vilhena
# Processing Record 42 of Set 6 | erzurum
# Processing Record 43 of Set 6 | russell
# Processing Record 44 of Set 6 | fazalpur
# Processing Record 45 of Set 6 | mantua
# Processing Record 46 of Set 6 | jacareacanga
# Processing Record 47 of Set 6 | dingle
# Processing Record 48 of Set 6 | sinnamary
# Processing Record 49 of Set 6 | puro
# Processing Record 50 of Set 6 | kisangani
# Processing Record 1 of Set 7 | berlevag
# Processing Record 2 of Set 7 | komsomolskiy
# Processing Record 3 of Set 7 | ngaoundere
# Processing Record 4 of Set 7 | orotukan
# Processing Record 5 of Set 7 | sioux lookout
# Processing Record 6 of Set 7 | coihaique
# Processing Record 7 of Set 7 | klaksvik
# Processing Record 8 of Set 7 | nevelsk
# Processing Record 9 of Set 7 | yuli
# Processing Record 10 of Set 7 | fortuna
# Processing Record 11 of Set 7 | kaeo
# Processing Record 12 of Set 7 | ust-koksa
# Processing Record 13 of Set 7 | pangkalanbuun
# Processing Record 14 of Set 7 | kruisfontein
# Processing Record 15 of Set 7 | sahaspur
# Processing Record 16 of Set 7 | gumdag
# Processing Record 17 of Set 7 | tubruq
# City not found. Skipping...
# Processing Record 18 of Set 7 | bonthe
# Processing Record 19 of Set 7 | shakawe
# Processing Record 20 of Set 7 | gigmoto
# Processing Record 21 of Set 7 | bethel
# Processing Record 22 of Set 7 | kristiinankaupunki
# Processing Record 23 of Set 7 | tomatlan
# Processing Record 24 of Set 7 | brawley
# Processing Record 25 of Set 7 | ust-maya
# Processing Record 26 of Set 7 | puurmani
# Processing Record 27 of Set 7 | tacuati
# Processing Record 28 of Set 7 | wote
# Processing Record 29 of Set 7 | birin
# Processing Record 30 of Set 7 | lagdo
# Processing Record 31 of Set 7 | finschhafen
# Processing Record 32 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 33 of Set 7 | andselv
# City not found. Skipping...
# Processing Record 34 of Set 7 | puerto escondido
# Processing Record 35 of Set 7 | port augusta
# Processing Record 36 of Set 7 | maine-soroa
# Processing Record 37 of Set 7 | ekhabi
# Processing Record 38 of Set 7 | la palma
# Processing Record 39 of Set 7 | lompoc
# Processing Record 40 of Set 7 | codrington
# Processing Record 41 of Set 7 | stefan cel mare
# Processing Record 42 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 7 | jesup
# Processing Record 44 of Set 7 | abnub
# Processing Record 45 of Set 7 | broken hill
# Processing Record 46 of Set 7 | saint-philippe
# Processing Record 47 of Set 7 | cudahy
# Processing Record 48 of Set 7 | dese
# Processing Record 49 of Set 7 | chapayeve
# Processing Record 50 of Set 7 | isangel
# Processing Record 1 of Set 8 | cap malheureux
# Processing Record 2 of Set 8 | santa cruz das palmeiras
# Processing Record 3 of Set 8 | san antonio
# Processing Record 4 of Set 8 | soyo
# Processing Record 5 of Set 8 | ulaanbaatar
# Processing Record 6 of Set 8 | basoko
# Processing Record 7 of Set 8 | mangrol
# Processing Record 8 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 9 of Set 8 | gushikawa
# Processing Record 10 of Set 8 | harper
# Processing Record 11 of Set 8 | kuliyapitiya
# Processing Record 12 of Set 8 | revda
# Processing Record 13 of Set 8 | fujinomiya
# Processing Record 14 of Set 8 | brigantine
# Processing Record 15 of Set 8 | anar darreh
# City not found. Skipping...
# Processing Record 16 of Set 8 | vanimo
# Processing Record 17 of Set 8 | sur
# Processing Record 18 of Set 8 | asau
# Processing Record 19 of Set 8 | leningradskiy
# Processing Record 20 of Set 8 | nova venecia
# Processing Record 21 of Set 8 | bossangoa
# Processing Record 22 of Set 8 | tecoanapa
# Processing Record 23 of Set 8 | lauro muller
# Processing Record 24 of Set 8 | kargasok
# Processing Record 25 of Set 8 | kutum
# Processing Record 26 of Set 8 | tessalit
# Processing Record 27 of Set 8 | anadyr
# Processing Record 28 of Set 8 | nhulunbuy
# Processing Record 29 of Set 8 | abu samrah
# Processing Record 30 of Set 8 | zaraza
# Processing Record 31 of Set 8 | tura
# Processing Record 32 of Set 8 | tongren
# Processing Record 33 of Set 8 | vila franca do campo
# Processing Record 34 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 35 of Set 8 | wilkie
# Processing Record 36 of Set 8 | pendleton
# Processing Record 37 of Set 8 | ca mau
# Processing Record 38 of Set 8 | farah
# Processing Record 39 of Set 8 | berdigestyakh
# Processing Record 40 of Set 8 | narsaq
# Processing Record 41 of Set 8 | ulagan
# Processing Record 42 of Set 8 | wajid
# Processing Record 43 of Set 8 | sarkand
# Processing Record 44 of Set 8 | biltine
# Processing Record 45 of Set 8 | sorland
# Processing Record 46 of Set 8 | homer
# Processing Record 47 of Set 8 | talcahuano
# Processing Record 48 of Set 8 | tokuyama
# Processing Record 49 of Set 8 | mwense
# Processing Record 50 of Set 8 | clyde river
# Processing Record 1 of Set 9 | ostrovnoy
# Processing Record 2 of Set 9 | dawson creek
# Processing Record 3 of Set 9 | falealupo
# City not found. Skipping...
# Processing Record 4 of Set 9 | aquiraz
# Processing Record 5 of Set 9 | gamba
# Processing Record 6 of Set 9 | bangassou
# Processing Record 7 of Set 9 | olinda
# Processing Record 8 of Set 9 | sipka
# City not found. Skipping...
# Processing Record 9 of Set 9 | bima
# Processing Record 10 of Set 9 | bialogard
# Processing Record 11 of Set 9 | meulaboh
# Processing Record 12 of Set 9 | loubomo
# Processing Record 13 of Set 9 | emerald
# Processing Record 14 of Set 9 | havelock
# Processing Record 15 of Set 9 | ferrol
# Processing Record 16 of Set 9 | port-cartier
# Processing Record 17 of Set 9 | marzuq
# Processing Record 18 of Set 9 | itaguai
# Processing Record 19 of Set 9 | quimper
# Processing Record 20 of Set 9 | corinto
# Processing Record 21 of Set 9 | sakakah
# Processing Record 22 of Set 9 | uray
# Processing Record 23 of Set 9 | lasa
# Processing Record 24 of Set 9 | west bay
# Processing Record 25 of Set 9 | dolores hidalgo
# Processing Record 26 of Set 9 | mochudi
# Processing Record 27 of Set 9 | chapais
# Processing Record 28 of Set 9 | muisne
# Processing Record 29 of Set 9 | bowmore
# Processing Record 30 of Set 9 | bonito
# Processing Record 31 of Set 9 | plouzane
# Processing Record 32 of Set 9 | kangaatsiaq
# Processing Record 33 of Set 9 | ghanzi
# Processing Record 34 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 35 of Set 9 | chake chake
# Processing Record 36 of Set 9 | sungaipenuh
# Processing Record 37 of Set 9 | mezen
# Processing Record 38 of Set 9 | tommot
# Processing Record 39 of Set 9 | ginir
# Processing Record 40 of Set 9 | sinjar
# Processing Record 41 of Set 9 | zhigansk
# Processing Record 42 of Set 9 | haines junction
# Processing Record 43 of Set 9 | karwar
# Processing Record 44 of Set 9 | saint-augustin
# Processing Record 45 of Set 9 | tateyama
# Processing Record 46 of Set 9 | goma
# Processing Record 47 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 48 of Set 9 | toftir
# City not found. Skipping...
# Processing Record 49 of Set 9 | namibe
# Processing Record 50 of Set 9 | esperance
# Processing Record 1 of Set 10 | cayenne
# Processing Record 2 of Set 10 | wentzville
# Processing Record 3 of Set 10 | yarim
# Processing Record 4 of Set 10 | yelan-koleno
# Processing Record 5 of Set 10 | shenjiamen
# Processing Record 6 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 7 of Set 10 | grindavik
# Processing Record 8 of Set 10 | machiques
# Processing Record 9 of Set 10 | okha
# Processing Record 10 of Set 10 | vostok
# Processing Record 11 of Set 10 | solovetskiy
# City not found. Skipping...
# Processing Record 12 of Set 10 | banda aceh
# Processing Record 13 of Set 10 | wichita falls
# Processing Record 14 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 15 of Set 10 | mount isa
# Processing Record 16 of Set 10 | arman
# Processing Record 17 of Set 10 | falun
# Processing Record 18 of Set 10 | ewa beach
# Processing Record 19 of Set 10 | korla
# Processing Record 20 of Set 10 | shelburne
# Processing Record 21 of Set 10 | gallup
# Processing Record 22 of Set 10 | albertville
# Processing Record 23 of Set 10 | iralaya
# Processing Record 24 of Set 10 | hami
# Processing Record 25 of Set 10 | los llanos de aridane
# Processing Record 26 of Set 10 | qasigiannguit
# Processing Record 27 of Set 10 | namatanai
# Processing Record 28 of Set 10 | obo
# Processing Record 29 of Set 10 | san andres
# Processing Record 30 of Set 10 | south venice
# Processing Record 31 of Set 10 | fallon
# Processing Record 32 of Set 10 | itarema
# Processing Record 33 of Set 10 | sakaiminato
# Processing Record 34 of Set 10 | kungurtug
# Processing Record 35 of Set 10 | esso
# Processing Record 36 of Set 10 | belyy yar
# Processing Record 37 of Set 10 | oxford
# Processing Record 38 of Set 10 | mpophomeni
# Processing Record 39 of Set 10 | roma
# Processing Record 40 of Set 10 | camocim
# Processing Record 41 of Set 10 | kuching
# Processing Record 42 of Set 10 | kaz
# Processing Record 43 of Set 10 | salalah
# Processing Record 44 of Set 10 | kasempa
# Processing Record 45 of Set 10 | leh
# Processing Record 46 of Set 10 | kamina
# Processing Record 47 of Set 10 | misratah
# Processing Record 48 of Set 10 | kautokeino
# Processing Record 49 of Set 10 | riberalta
# Processing Record 50 of Set 10 | selfoss
# Processing Record 1 of Set 11 | santa rosalia
# Processing Record 2 of Set 11 | mnogovershinnyy
# Processing Record 3 of Set 11 | neuquen
# Processing Record 4 of Set 11 | cockburn town
# Processing Record 5 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 6 of Set 11 | tocache
# Processing Record 7 of Set 11 | camacha
# Processing Record 8 of Set 11 | araguari
# Processing Record 9 of Set 11 | roebourne
# Processing Record 10 of Set 11 | jumla
# Processing Record 11 of Set 11 | verkhnevilyuysk
# Processing Record 12 of Set 11 | rosetown
# Processing Record 13 of Set 11 | lunavada
# Processing Record 14 of Set 11 | muzhi
# Processing Record 15 of Set 11 | montgomery
# Processing Record 16 of Set 11 | draguignan
# Processing Record 17 of Set 11 | warren
# Processing Record 18 of Set 11 | rusape
# Processing Record 19 of Set 11 | krasnousolskiy
# City not found. Skipping...
# Processing Record 20 of Set 11 | srednekolymsk
# Processing Record 21 of Set 11 | marsh harbour
# Processing Record 22 of Set 11 | foz
# Processing Record 23 of Set 11 | roald
# Processing Record 24 of Set 11 | qianguo
# Processing Record 25 of Set 11 | zharkent
# Processing Record 26 of Set 11 | aktash
# Processing Record 27 of Set 11 | rovaniemi
# Processing Record 28 of Set 11 | pemangkat
# Processing Record 29 of Set 11 | kerki
# City not found. Skipping...
# Processing Record 30 of Set 11 | marau
# Processing Record 31 of Set 11 | zima
# Processing Record 32 of Set 11 | diamantina
# Processing Record 33 of Set 11 | vanavara
# Processing Record 34 of Set 11 | waingapu
# Processing Record 35 of Set 11 | coxim
# Processing Record 36 of Set 11 | albanel
# Processing Record 37 of Set 11 | ketchenery
# City not found. Skipping...
# Processing Record 38 of Set 11 | vardo
# Processing Record 39 of Set 11 | houma
# Processing Record 40 of Set 11 | san ramon
# Processing Record 41 of Set 11 | novopokrovka
# Processing Record 42 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 43 of Set 11 | kieta
# Processing Record 44 of Set 11 | chippenham
# Processing Record 45 of Set 11 | golden
# Processing Record 46 of Set 11 | marawi
# Processing Record 47 of Set 11 | longyearbyen
# Processing Record 48 of Set 11 | muros
# Processing Record 49 of Set 11 | chimbote
# Processing Record 50 of Set 11 | nemuro
# Processing Record 1 of Set 12 | charters towers
# Processing Record 2 of Set 12 | morvi
# Processing Record 3 of Set 12 | mehamn
# Processing Record 4 of Set 12 | vestmannaeyjar
# Processing Record 5 of Set 12 | santiago atitlan
# Processing Record 6 of Set 12 | jurado
# Processing Record 7 of Set 12 | zhaotong
# Processing Record 8 of Set 12 | taltal
# Processing Record 9 of Set 12 | teguldet
# Processing Record 10 of Set 12 | le port
# Processing Record 11 of Set 12 | archidona
# Processing Record 12 of Set 12 | dezhou
# Processing Record 13 of Set 12 | sao joao da barra
# Processing Record 14 of Set 12 | santona
# Processing Record 15 of Set 12 | ereymentau
# Processing Record 16 of Set 12 | los andes
# Processing Record 17 of Set 12 | mahina
# Processing Record 18 of Set 12 | lorengau
# Processing Record 19 of Set 12 | bairiki
# Processing Record 20 of Set 12 | kushiro
# Processing Record 21 of Set 12 | el mahalla el kubra
# City not found. Skipping...
# Processing Record 22 of Set 12 | prince rupert
# Processing Record 23 of Set 12 | quatre cocos
# Processing Record 24 of Set 12 | cloquet
# Processing Record 25 of Set 12 | abalak
# Processing Record 26 of Set 12 | hit
# Processing Record 27 of Set 12 | matagami
# Processing Record 28 of Set 12 | great yarmouth
# Processing Record 29 of Set 12 | wahiawa
# Processing Record 30 of Set 12 | biak
# Processing Record 31 of Set 12 | esna
# Processing Record 32 of Set 12 | dickson
# Processing Record 33 of Set 12 | deming
# Processing Record 34 of Set 12 | ust-ishim
# Processing Record 35 of Set 12 | calama
# Processing Record 36 of Set 12 | flinders
# Processing Record 37 of Set 12 | kavaratti
# Processing Record 38 of Set 12 | itapora
# Processing Record 39 of Set 12 | pauini
# Processing Record 40 of Set 12 | candelaria
# Processing Record 41 of Set 12 | nador
# Processing Record 42 of Set 12 | sistranda
# Processing Record 43 of Set 12 | meybod
# Processing Record 44 of Set 12 | virginia beach
# Processing Record 45 of Set 12 | wasilla
# Processing Record 46 of Set 12 | bor
# Processing Record 47 of Set 12 | high level
# Processing Record 48 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 49 of Set 12 | semey
# Processing Record 50 of Set 12 | bellmead
# Processing Record 1 of Set 13 | yerbogachen
# Processing Record 2 of Set 13 | mariakani
# Processing Record 3 of Set 13 | riosucio
# Processing Record 4 of Set 13 | casper
# Processing Record 5 of Set 13 | hukuntsi
# Processing Record 6 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 13 | kahului
# Processing Record 8 of Set 13 | alice springs
# Processing Record 9 of Set 13 | maningrida
# Processing Record 10 of Set 13 | old road
# City not found. Skipping...
# Processing Record 11 of Set 13 | igrim
# Processing Record 12 of Set 13 | hamakita
# Processing Record 13 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 14 of Set 13 | bandarbeyla
# Processing Record 15 of Set 13 | clonmel
# Processing Record 16 of Set 13 | brokopondo
# Processing Record 17 of Set 13 | ojinaga
# Processing Record 18 of Set 13 | northam
# Processing Record 19 of Set 13 | ecoporanga
# Processing Record 20 of Set 13 | angoche
# Processing Record 21 of Set 13 | shache
# Processing Record 22 of Set 13 | tigil
# Processing Record 23 of Set 13 | saint-francois
# Processing Record 24 of Set 13 | trairi
# Processing Record 25 of Set 13 | ternate
# Processing Record 26 of Set 13 | batagay
# Processing Record 27 of Set 13 | kamenka
# Processing Record 28 of Set 13 | amuntai
# Processing Record 29 of Set 13 | kemi
# Processing Record 30 of Set 13 | ippy
# Processing Record 31 of Set 13 | eyl
# Processing Record 32 of Set 13 | puerto leguizamo
# Processing Record 33 of Set 13 | iernut
# Processing Record 34 of Set 13 | gat
# Processing Record 35 of Set 13 | taksimo
# Processing Record 36 of Set 13 | filadelfia
# Processing Record 37 of Set 13 | gavrilov posad
# Processing Record 38 of Set 13 | borama
# City not found. Skipping...
# Processing Record 39 of Set 13 | snasa
# Processing Record 40 of Set 13 | praia da vitoria
# Processing Record 41 of Set 13 | san quintin
# Processing Record 42 of Set 13 | oussouye
# Processing Record 43 of Set 13 | riyadh
# Processing Record 44 of Set 13 | dandong
# Processing Record 45 of Set 13 | labuhan
# Processing Record 46 of Set 13 | laurens
# Processing Record 47 of Set 13 | kayes
# Processing Record 48 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 49 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 50 of Set 13 | paita
# Processing Record 1 of Set 14 | cravo norte
# Processing Record 2 of Set 14 | sumbe
# Processing Record 3 of Set 14 | kinsale
# Processing Record 4 of Set 14 | suoyarvi
# Processing Record 5 of Set 14 | neryungri
# Processing Record 6 of Set 14 | toora-khem
# Processing Record 7 of Set 14 | bhaderwah
# Processing Record 8 of Set 14 | nelson bay
# Processing Record 9 of Set 14 | oksfjord
# Processing Record 10 of Set 14 | serov
# Processing Record 11 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 12 of Set 14 | chippewa falls
# Processing Record 13 of Set 14 | hobyo
# Processing Record 14 of Set 14 | sibolga
# Processing Record 15 of Set 14 | batagay-alyta
# Processing Record 16 of Set 14 | bokspits
# City not found. Skipping...
# Processing Record 17 of Set 14 | touros
# Processing Record 18 of Set 14 | mozarlandia
# Processing Record 19 of Set 14 | bani
# Processing Record 20 of Set 14 | campbellsville
# Processing Record 21 of Set 14 | norrtalje
# Processing Record 22 of Set 14 | jinzhou
# Processing Record 23 of Set 14 | mecca
# Processing Record 24 of Set 14 | tual
# Processing Record 25 of Set 14 | jinka
# Processing Record 26 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 27 of Set 14 | oda
# Processing Record 28 of Set 14 | cervo
# Processing Record 29 of Set 14 | along
# Processing Record 30 of Set 14 | havre-saint-pierre
# Processing Record 31 of Set 14 | magadan
# Processing Record 32 of Set 14 | preobrazheniye
# Processing Record 33 of Set 14 | sandwick
# Processing Record 34 of Set 14 | teguise
# Processing Record 35 of Set 14 | oktyabrskiy
# Processing Record 36 of Set 14 | half moon bay
# Processing Record 37 of Set 14 | santa rosa
# Processing Record 38 of Set 14 | barra patuca
# Processing Record 39 of Set 14 | atar
# Processing Record 40 of Set 14 | batangafo
# Processing Record 41 of Set 14 | aksu
# Processing Record 42 of Set 14 | saint anthony
# Processing Record 43 of Set 14 | hinton
# Processing Record 44 of Set 14 | mindyak
# Processing Record 45 of Set 14 | mandalgovi
# Processing Record 46 of Set 14 | uyuni
# Processing Record 47 of Set 14 | dongli
# Processing Record 48 of Set 14 | raga
# Processing Record 49 of Set 14 | merauke
# Processing Record 50 of Set 14 | bon accord
# Processing Record 1 of Set 15 | lima
# Processing Record 2 of Set 15 | kyabe
# Processing Record 3 of Set 15 | ketchikan
# Processing Record 4 of Set 15 | atambua
# Processing Record 5 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 15 | saint-pierre
# Processing Record 7 of Set 15 | kerman
# Processing Record 8 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 9 of Set 15 | jasper
# Processing Record 10 of Set 15 | kaspiyskiy
# Processing Record 11 of Set 15 | quzhou
# Processing Record 12 of Set 15 | lubango
# Processing Record 13 of Set 15 | hvide sande
# Processing Record 14 of Set 15 | bud
# Processing Record 15 of Set 15 | french harbor
# Processing Record 16 of Set 15 | ningxiang
# Processing Record 17 of Set 15 | kearney
# Processing Record 18 of Set 15 | pimentel
# Processing Record 19 of Set 15 | viedma
# Processing Record 20 of Set 15 | imbituba
# Processing Record 21 of Set 15 | fort nelson
# Processing Record 22 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 23 of Set 15 | arkadak
# Processing Record 24 of Set 15 | shieli
# Processing Record 25 of Set 15 | boende
# Processing Record 26 of Set 15 | kot putli
# City not found. Skipping...
# Processing Record 27 of Set 15 | turukhansk
# Processing Record 28 of Set 15 | marsa matruh
# Processing Record 29 of Set 15 | faridpur
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Hilo      US  19.7297 -155.0900     78.53        85         100
# 1  Punta Arenas      CL -53.1500  -70.9167     46.51        71          75
# 2         Bouar      CF   5.9340   15.5960     71.17        21          37
# 3        Castro      BR -24.7911  -50.0119     65.55        95          92
# 4       Ushuaia      AR -54.8000  -68.3000     40.62        81          75
# 5       Rikitea      PF -23.1203 -134.9692     79.72        81          82
# 6         Alofi      NU -19.0595 -169.9187     82.29        89          75
# 7       Gobabis      NA -22.4500   18.9667     66.47        30           0
# 8        Albany      US  42.6001  -73.9662     57.63        51          16
# 9  Puerto Ayora      EC  -0.7393  -90.3518     85.96        80          93
#
#    Wind Speed Current Description
# 0       11.50       moderate rain
# 1       16.11       broken clouds
# 2        4.85    scattered clouds
# 3        5.68     overcast clouds
# 4       13.80          light rain
# 5       24.32          light rain
# 6        4.61       broken clouds
# 7       10.40           clear sky
# 8        1.99          few clouds
# 9        4.00     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
